# %%
import pandas as pd 
df = pd.read_csv("C:\\Python EDA\\projets by pyhon\\customer_shopping_behavior_50k.csv")
df.head(100)
# Out:
#     Customer_ID  Age  Gender        Location Item_Purchased     Category Size  \
# 0             1   56    Male            Ohio        Sandals    Outerwear    L
# 1             2   69  Female      California          Shoes     Clothing    L
# 2             3   46  Female         Florida          Jeans  Accessories   XL
# 3             4   32    Male        New York           Coat    Outerwear    M
# 4             5   60    Male        Virginia         Shorts     Footwear    M
# ..          ...  ...     ...             ...            ...          ...  ...
# 95           96   42    Male         Florida        Sweater     Footwear    S
# 96           97   62  Female        Virginia        Sandals     Footwear    S
# 97           98   58  Female        Virginia         Blouse     Footwear   XS
# 98           99   46  Female  North Carolina          Pants  Accessories    S
# 99          100   32    Male         Georgia        Handbag     Footwear    S
#
# ...

# %%
df.shape
# Out:
# (50000, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer_ID            50000 non-null  int64
#  1   Age                    50000 non-null  int64
#  2   Gender                 50000 non-null  object
#  3   Location               50000 non-null  object
#  4   Item_Purchased         50000 non-null  object
#  5   Category               50000 non-null  object
#  6   Size                   50000 non-null  object
#  7   Color                  50000 non-null  object
#  8   Season                 50000 non-null  object
#  9   Price                  50000 non-null  float64
#  10  Discount (%)           50000 non-null  int64
#  11  Rating                 50000 non-null  float64
#  12  Shipping_Type          50000 non-null  object
#  13  Subscription           50000 non-null  object
# ...

# %%
df.describe(include="all")
# Out:
#          Customer_ID           Age  Gender    Location Item_Purchased  \
# count   50000.000000  50000.000000   50000       50000          50000
# unique           NaN           NaN       3          10             14
# top              NaN           NaN  Female  California          Skirt
# freq             NaN           NaN   24122        5084           3645
# mean    25000.500000     43.508260     NaN         NaN            NaN
# std     14433.901067     14.987668     NaN         NaN            NaN
# min         1.000000     18.000000     NaN         NaN            NaN
# 25%     12500.750000     31.000000     NaN         NaN            NaN
# 50%     25000.500000     43.000000     NaN         NaN            NaN
# 75%     37500.250000     56.000000     NaN         NaN            NaN
# max     50000.000000     69.000000     NaN         NaN            NaN
#
#         Category   Size  Color  Season         Price  ...  Subscription  \
# ...

# %%
df.isnull().sum()
# Out:
# Customer_ID              0
# Age                      0
# Gender                   0
# Location                 0
# Item_Purchased           0
# Category                 0
# Size                     0
# Color                    0
# Season                   0
# Price                    0
# Discount (%)             0
# Rating                   0
# Shipping_Type            0
# Subscription             0
# Promo_Code_Used          0
# Previous_Purchases       0
# Payment_Method           0
# Frequency_of_Purchase    0
# Return_Status            0
# Delivery_Time (Days)     0
# Customer_Satisfaction    0
# Purchase_Date            0
# Total_Spent              0
# dtype: int64

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ', '-')

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'location', 'item_purchased',
#        'category', 'size', 'color', 'season', 'price', 'discount-(%)',
#        'rating', 'shipping_type', 'subscription', 'promo_code_used',
#        'previous_purchases', 'payment_method', 'frequency_of_purchase',
#        'return_status', 'delivery_time-(days)', 'customer_satisfaction',
#        'purchase_date', 'total_spent'],
#       dtype='object')

# %%
df = df.rename(columns={'discount-(%)': 'discount(%)'})

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'location', 'item_purchased',
#        'category', 'size', 'color', 'season', 'price', 'discount(%)', 'rating',
#        'shipping_type', 'subscription', 'promo_code_used',
#        'previous_purchases', 'payment_method', 'frequency_of_purchase',
#        'return_status', 'delivery_time-(days)', 'customer_satisfaction',
#        'purchase_date', 'total_spent'],
#       dtype='object')

# %%
import pandas as pd
labels = ['Young Adult', 'Adult', 'Middle Aged', 'Senior']
df['age_group'] = pd.qcut(df['age'], q=4, labels=labels)

# %%
df[['age','age_group']].head(10)
# Out:
#    age    age_group
# 0   56  Middle Aged
# 1   69       Senior
# 2   46  Middle Aged
# 3   32        Adult
# 4   60       Senior
# 5   25  Young Adult
# 6   38        Adult
# 7   56  Middle Aged
# 8   36        Adult
# 9   40        Adult

# %%
# Correct mapping dictionary
frequency_mapping = {
    'Fortnightly': 14,
    'Weekly': 7,
    'Monthly': 30,
    'Quarterly': 90,
    'Bi-Weekly': 14,
    'Annually': 365,
    'Every 3 months': 90
}

# Map to new column
df['frequency_of_mapping'] = df['frequency_of_purchase'].str.strip().map(frequency_mapping)

# %%
df[['frequency_of_mapping', 'frequency_of_purchase']].head(10)
# Out:
#    frequency_of_mapping frequency_of_purchase
# 0                   365              Annually
# 1                    90             Quarterly
# 2                    14             Bi-Weekly
# 3                    14             Bi-Weekly
# 4                   365              Annually
# 5                     7                Weekly
# 6                    30               Monthly
# 7                   365              Annually
# 8                     7                Weekly
# 9                    90             Quarterly

# %%
df[['discount(%)','promo_code_used']].head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df[['discount(%)','promo_code_used']].head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df['age'], bins=20, kde=True, color='teal')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
top_items = df['item_purchased'].value_counts().head(10)
sns.barplot(x = top_items.values, y = top_items.index, palette='viridis')
plt.title('Top 10 Most Purchased Items')
plt.xlabel('Purchase Count')
plt.show()
# Out:
# C:\Users\shams\AppData\Local\Temp\ipykernel_14504\2788654234.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = top_items.values, y = top_items.index, palette='viridis')

# %%
sns.countplot(y='category', data=df, order=df['category'].value_counts().index, palette='cool')
plt.title('Category-wise Purchases')
plt.show()
# Out:
# C:\Users\shams\AppData\Local\Temp\ipykernel_14504\4101146476.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='category', data=df, order=df['category'].value_counts().index, palette='cool')

# %%
avg_price = df.groupby('category')['price'].mean().sort_values(ascending=False)
sns.barplot(x=avg_price.values, y=avg_price.index, palette='magma')
plt.title('Average Price per Category')
plt.xlabel('Average Price')
plt.show()
# Out:
# C:\Users\shams\AppData\Local\Temp\ipykernel_14504\322910492.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_price.values, y=avg_price.index, palette='magma')

# %%
sns.scatterplot(x='price', y='discount(%)', data=df, hue='category', alpha=0.7)
plt.title('Price vs Discount (%)')
plt.show()

# %%
sns.boxplot(x='category', y='customer_satisfaction', data=df, palette='Set2')
plt.title('Customer Satisfaction by Category')
plt.xticks(rotation=45)
plt.show()

# %%
sns.scatterplot(x='delivery_time-(days)', y='rating', data=df, hue='season', alpha=0.6)
plt.title('Delivery Time vs Customer Rating')
plt.show()

# %%
numeric_cols = df.select_dtypes(include='number')
sns.heatmap(numeric_cols.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.barplot(
    x='season',
    y='total_spent',
    data=df,
    estimator=sum,
    hue='season',        # Add hue to apply palette safely
    palette='winter',
    legend=False         # Hide duplicate legend
)
plt.title('Total Spending by Season')
plt.xlabel('Season')
plt.ylabel('Total Spent')
plt.show()

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Customer_ID  Age  Gender    Location Item_Purchased     Category Size  \
# 0                1   56    Male        Ohio        Sandals    Outerwear    L
# 1                2   69  Female  California          Shoes     Clothing    L
# 2                3   46  Female     Florida          Jeans  Accessories   XL
# 3                4   32    Male    New York           Coat    Outerwear    M
# 4                5   60    Male    Virginia         Shorts     Footwear    M
# ...            ...  ...     ...         ...            ...          ...  ...
# 49995        49996   66    Male        Ohio          Pants     Clothing    S
# 49996        49997   35  Female        Ohio       Sneakers     Clothing   XS
# 49997        49998   28    Male    Michigan        Handbag     Clothing   XL
# 49998        49999   59  Female        Ohio     Sunglasses     Clothing    S
# 49999        50000   35  Female    New York        Handbag     Footwear    S
#
# ...

# %%
from sqlalchemy import create_engine

# তোমার MySQL details অনুযায়ী নিচের লাইনটা বদলাও
engine = create_engine("mysql+mysqlconnector://root:23120133@localhost/test_db")

# %%
df.to_sql('customer_data', con=engine, if_exists='replace', index=False)
print("✅ DataFrame successfully sent to MySQL!")
# Out:
# ✅ DataFrame successfully sent to MySQL!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer_ID            50000 non-null  int64
#  1   Age                    50000 non-null  int64
#  2   Gender                 50000 non-null  object
#  3   Location               50000 non-null  object
#  4   Item_Purchased         50000 non-null  object
#  5   Category               50000 non-null  object
#  6   Size                   50000 non-null  object
#  7   Color                  50000 non-null  object
#  8   Season                 50000 non-null  object
#  9   Price                  50000 non-null  float64
#  10  Discount (%)           50000 non-null  int64
#  11  Rating                 50000 non-null  float64
#  12  Shipping_Type          50000 non-null  object
#  13  Subscription           50000 non-null  object
# ...
